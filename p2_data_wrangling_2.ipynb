# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('student.csv')
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# 12  female        74.0           79.0             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
df.shape
# Out:
# (13, 7)

# %%
df.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count   12.000000      12.000000      13.000000        11.000000
# mean    57.750000      82.583333      55.692308        72.818182
# std     50.018406       3.260182      46.894180        57.332047
# min    -99.000000      79.000000     -99.000000       -99.000000
# 25%     65.500000      79.750000      64.000000        84.500000
# 50%     70.500000      82.500000      66.000000        87.000000
# 75%     74.250000      85.250000      76.000000        95.500000
# max     94.000000      88.000000      79.000000       100.000000
#
#        club join year  placement offer
# count       13.000000        13.000000
# mean      2019.692308         2.000000
# std          1.031553         0.816497
# min       2018.000000         1.000000
# 25%       2019.000000         1.000000
# 50%       2020.000000         2.000000
# 75%       2020.000000         3.000000
# max       2021.000000         3.000000

# %%
df.isnull()
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0    False       False          False          False            False
# 1    False       False          False          False            False
# 2    False       False          False          False            False
# 3    False       False          False          False            False
# 4    False       False          False          False             True
# 5    False       False          False          False            False
# 6    False       False          False          False            False
# 7    False        True           True          False            False
# 8    False       False          False          False            False
# 9    False       False          False          False            False
# 10   False       False          False          False            False
# 11   False       False          False          False             True
# 12   False       False          False          False            False
#
#     club join year  placement offer
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
# 5            False            False
# 6            False            False
# 7            False            False
# 8            False            False
# 9            False            False
# 10           False            False
# 11           False            False
# 12           False            False

# %%
df.isnull().sum()
# Out:
# gender             0
# math score         1
# reading score      1
# writing score      0
# placement score    2
# club join year     0
# placement offer    0
# dtype: int64

# %%
df.dtypes
# Out:
# gender              object
# math score         float64
# reading score      float64
# writing score        int64
# placement score    float64
# club join year       int64
# placement offer      int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder ()
df['gender'] = le.fit_transform(df['gender'])
newdf=df
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0        63.0           84.0             64             84.0
# 1        0        71.0           80.0             76             86.0
# 2        0        64.0           81.0             66             81.0
# 3        1        71.0           85.0             77             96.0
# 4        1        68.0           86.0             76              NaN
# 5        0        94.0           86.0             61            100.0
# 6        1        75.0           79.0             66            -99.0
# 7        0         NaN            NaN             66             95.0
# 8        1        66.0           88.0             66             88.0
# 9        1        70.0           79.0             61             87.0
# 10       0       -99.0           80.0             65             85.0
# 11       1        76.0           84.0            -99              NaN
# 12       0        74.0           79.0             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf=df
ndf.fillna(0)
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0        63.0           84.0             64             84.0
# 1        0        71.0           80.0             76             86.0
# 2        0        64.0           81.0             66             81.0
# 3        1        71.0           85.0             77             96.0
# 4        1        68.0           86.0             76              0.0
# 5        0        94.0           86.0             61            100.0
# 6        1        75.0           79.0             66            -99.0
# 7        0         0.0            0.0             66             95.0
# 8        1        66.0           88.0             66             88.0
# 9        1        70.0           79.0             61             87.0
# 10       0       -99.0           80.0             65             85.0
# 11       1        76.0           84.0            -99              0.0
# 12       0        74.0           79.0             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
m_v=df['math score'].mean() 
df['math score'].fillna(value=m_v, inplace=True) 
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0       63.00           84.0             64             84.0
# 1        0       71.00           80.0             76             86.0
# 2        0       64.00           81.0             66             81.0
# 3        1       71.00           85.0             77             96.0
# 4        1       68.00           86.0             76              NaN
# 5        0       94.00           86.0             61            100.0
# 6        1       75.00           79.0             66            -99.0
# 7        0       57.75            NaN             66             95.0
# 8        1       66.00           88.0             66             88.0
# 9        1       70.00           79.0             61             87.0
# 10       0      -99.00           80.0             65             85.0
# 11       1       76.00           84.0            -99              NaN
# 12       0       74.00           79.0             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
m_v=df['reading score'].mean()
df['reading score'].fillna(value=m_v, inplace=True)
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0       63.00      84.000000             64             84.0
# 1        0       71.00      80.000000             76             86.0
# 2        0       64.00      81.000000             66             81.0
# 3        1       71.00      85.000000             77             96.0
# 4        1       68.00      86.000000             76              NaN
# 5        0       94.00      86.000000             61            100.0
# 6        1       75.00      79.000000             66            -99.0
# 7        0       57.75      82.583333             66             95.0
# 8        1       66.00      88.000000             66             88.0
# 9        1       70.00      79.000000             61             87.0
# 10       0      -99.00      80.000000             65             85.0
# 11       1       76.00      84.000000            -99              NaN
# 12       0       74.00      79.000000             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0       63.00      84.000000             64             84.0
# 1        0       71.00      80.000000             76             86.0
# 2        0       64.00      81.000000             66             81.0
# 3        1       71.00      85.000000             77             96.0
# 4        1       68.00      86.000000             76            -99.0
# 5        0       94.00      86.000000             61            100.0
# 6        1       75.00      79.000000             66            -99.0
# 7        0       57.75      82.583333             66             95.0
# 8        1       66.00      88.000000             66             88.0
# 9        1       70.00      79.000000             61             87.0
# 10       0      -99.00      80.000000             65             85.0
# 11       1       76.00      84.000000            -99            -99.0
# 12       0       74.00      79.000000             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf.dropna
# Out:
# <bound method DataFrame.dropna of     gender  math score  reading score  writing score  placement score  \
# 0        0       63.00      84.000000             64             84.0
# 1        0       71.00      80.000000             76             86.0
# 2        0       64.00      81.000000             66             81.0
# 3        1       71.00      85.000000             77             96.0
# 4        1       68.00      86.000000             76              NaN
# 5        0       94.00      86.000000             61            100.0
# 6        1       75.00      79.000000             66            -99.0
# 7        0       57.75      82.583333             66             95.0
# 8        1       66.00      88.000000             66             88.0
# 9        1       70.00      79.000000             61             87.0
# 10       0      -99.00      80.000000             65             85.0
# 11       1       76.00      84.000000            -99              NaN
# 12       0       74.00      79.000000             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2  >

# %%
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0       63.00      84.000000             64             84.0
# 1        0       71.00      80.000000             76             86.0
# 2        0       64.00      81.000000             66             81.0
# 3        1       71.00      85.000000             77             96.0
# 4        1       68.00      86.000000             76              NaN
# 5        0       94.00      86.000000             61            100.0
# 6        1       75.00      79.000000             66            -99.0
# 7        0       57.75      82.583333             66             95.0
# 8        1       66.00      88.000000             66             88.0
# 9        1       70.00      79.000000             61             87.0
# 10       0      -99.00      80.000000             65             85.0
# 11       1       76.00      84.000000            -99              NaN
# 12       0       74.00      79.000000             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        0       63.00      84.000000             64             84.0
# 1        0       71.00      80.000000             76             86.0
# 2        0       64.00      81.000000             66             81.0
# 3        1       71.00      85.000000             77             96.0
# 4        1       68.00      86.000000             76            -99.0
# 5        0       94.00      86.000000             61            100.0
# 6        1       75.00      79.000000             66            -99.0
# 7        0       57.75      82.583333             66             95.0
# 8        1       66.00      88.000000             66             88.0
# 9        1       70.00      79.000000             61             87.0
# 10       0      -99.00      80.000000             65             85.0
# 11       1       76.00      84.000000            -99            -99.0
# 12       0       74.00      79.000000             79             98.0
#
#     club join year  placement offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
col =['reading score', 'reading score', 'writing score', 'placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math score']>90)) 
print(np.where(df['reading score']<25)) 
print(np.where(df['writing score']<40))
# Out:
# (array([5], dtype=int64),)
# (array([], dtype=int64),)
# (array([11], dtype=int64),)

# %%
fig, ax =plt.subplots(figsize = (18,10))
ax.scatter(df['reading score'], df['writing score'])
plt.show()
ax.set_xlabel('(Proportion non-retail business acres)/(town)')#optional
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')#optional
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['reading score'], 90)
b = np.where(df_stud['reading score']>ninetieth_percentile,ninetieth_percentile, df_stud['reading score'])
print("New array:",b)

#col = ['reading score','writing score']
#df.boxplot(col)
# Out:
# New array: [84.         80.         81.         85.         86.         86.
#  79.         82.58333333 86.         79.         80.         84.
#  79.        ]

# %%
import matplotlib.pyplot as plt
df['reading score'].plot(kind ='hist')
df['log_math'] = np.log10(df['reading score'])
plt.show()

# %%
df['log_math'].plot(kind = 'hist')
plt.show()
